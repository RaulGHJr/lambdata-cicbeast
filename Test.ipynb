# %%
import numpy as np
import pandas as pd
from scipy.stats import chisquare

# %%
# !pip install -i https://test.pypi.org/simple/ lambdata-cicbeast

# %%
from lambdata_cicbeast import cont_chi2

# %%
df = pd.read_csv('https://math.tntech.edu/e-stat/DASL/popularkids.txt', sep='\t')
df.head()
# Out:
#   Gender  Grade  Age   Race Urban.Rural School    Goals  Grades  Sports  \
# 0    boy      5   11  White       Rural    Elm   Sports       1       2
# 1    boy      5   10  White       Rural    Elm  Popular       2       1
# 2   girl      5   11  White       Rural    Elm  Popular       4       3
# 3   girl      5   11  White       Rural    Elm  Popular       2       3
# 4   girl      5   10  White       Rural    Elm  Popular       4       2
#
#    Looks  Money
# 0      4      3
# 1      4      3
# 2      1      2
# 3      4      1
# 4      1      3

# %%
cont_chi2(df['Goals'], df['Grade'])
# Out:
# (Grade     4   5   6
#  Goals
#  Grades   63  88  96
#  Popular  31  55  55
#  Sports   25  33  32, array([21.04201681, 26.125     , 34.45901639]))

# %%
from lambdata_cicbeast import date_sep

# %%
train = pd.read_csv('https://drive.google.com/uc?export=download&id=1E9rgiGf1f_WL2S4-V6gD7ZhB8r8Yb_lE')
train.head()
# Out:
#    Store  DayOfWeek        Date  Sales  Customers  Promo  SchoolHoliday
# 0      4          5  2015-07-31  13995       1498      1              1
# 1      8          5  2015-07-31   8492        833      1              1
# 2     11          5  2015-07-31  10457       1236      1              1
# 3     12          5  2015-07-31   8959        962      1              1
# 4     34          5  2015-07-31  11144       1162      1              1

# %%
train = train.rename(columns={'Date':'date'})
train.head()
# Out:
#    Store  DayOfWeek        date  Sales  Customers  Promo  SchoolHoliday
# 0      4          5  2015-07-31  13995       1498      1              1
# 1      8          5  2015-07-31   8492        833      1              1
# 2     11          5  2015-07-31  10457       1236      1              1
# 3     12          5  2015-07-31   8959        962      1              1
# 4     34          5  2015-07-31  11144       1162      1              1

# %%
date_sep(train)
train.head()
# Out:
#    Store  DayOfWeek       date  Sales  Customers  Promo  SchoolHoliday  year  \
# 0      4          5 2015-07-31  13995       1498      1              1  2015
# 1      8          5 2015-07-31   8492        833      1              1  2015
# 2     11          5 2015-07-31  10457       1236      1              1  2015
# 3     12          5 2015-07-31   8959        962      1              1  2015
# 4     34          5 2015-07-31  11144       1162      1              1  2015
#
#    month  day
# 0      7   31
# 1      7   31
# 2      7   31
# 3      7   31
# 4      7   31
